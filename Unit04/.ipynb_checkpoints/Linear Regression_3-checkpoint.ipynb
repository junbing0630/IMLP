# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.5360598307165048

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5] for k in x])  # add k**6 to try it
print(X_poly.shape)
# Out:
# (100, 5)

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_poly.predict(X_poly), 'r')

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [-1.68414688  2.28686016 -1.07638241  0.23682871 -0.01885943]
# interception:  1.1399614524158315

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([1.13996145, 1.06059963, 0.99209366, 0.93366608, 0.88457495,
#        0.84411303, 0.81160714, 0.78641733, 0.76793618, 0.75558804,
#        0.7488283 , 0.74714264, 0.75004628, 0.75708323, 0.76782557,
#        0.78187271, 0.79885059, 0.81841102, 0.84023085, 0.8640113 ,
#        0.88947718, 0.91637614, 0.94447795, 0.97357373, 1.00347525,
#        1.03401412, 1.06504111, 1.09642536, 1.12805368, 1.15982976,
#        1.19167345, 1.22352004, 1.25531946, 1.28703558, 1.31864546,
#        1.3501386 , 1.38151618, 1.41279035, 1.44398346, 1.47512733,
#        1.50626251, 1.5374375 , 1.56870807, 1.60013646, 1.63179066,
#        1.66374366, 1.69607272, 1.72885861, 1.76218487, 1.79613708,
#        1.83080209, 1.86626729, 1.9026199 , 1.93994614, 1.97833059,
#        2.01785538, 2.05859944, 2.10063782, 2.14404088, 2.18887356,
#        2.23519469, 2.28305616, 2.33250226, 2.38356886, 2.43628273,
#        2.49066076, 2.54670923, 2.60442305, 2.66378506, 2.72476522,
#        2.78731991, 2.8513912 , 2.91690606, 2.98377565, 3.05189457,
#        3.12114009, 3.19137147, 3.26242914, 3.33413402, 3.40628672,
#        3.47866684, 3.55103222, 3.62311818, 3.69463676, 3.76527605,
#        3.83469935, 3.90254449, 3.96842307, 4.03191973, 4.09259136,
#        4.14996641, 4.20354413, 4.25279379, 4.297154  , 4.33603191,
#        4.36880252, 4.39480786, 4.41335633, 4.42372191, 4.42514342])

# %%
regr_poly.predict(X_poly)
# Out:
# array([1.13996145, 1.06059963, 0.99209366, 0.93366608, 0.88457495,
#        0.84411303, 0.81160714, 0.78641733, 0.76793618, 0.75558804,
#        0.7488283 , 0.74714264, 0.75004628, 0.75708323, 0.76782557,
#        0.78187271, 0.79885059, 0.81841102, 0.84023085, 0.8640113 ,
#        0.88947718, 0.91637614, 0.94447795, 0.97357373, 1.00347525,
#        1.03401412, 1.06504111, 1.09642536, 1.12805368, 1.15982976,
#        1.19167345, 1.22352004, 1.25531946, 1.28703558, 1.31864546,
#        1.3501386 , 1.38151618, 1.41279035, 1.44398346, 1.47512733,
#        1.50626251, 1.5374375 , 1.56870807, 1.60013646, 1.63179066,
#        1.66374366, 1.69607272, 1.72885861, 1.76218487, 1.79613708,
#        1.83080209, 1.86626729, 1.9026199 , 1.93994614, 1.97833059,
#        2.01785538, 2.05859944, 2.10063782, 2.14404088, 2.18887356,
#        2.23519469, 2.28305616, 2.33250226, 2.38356886, 2.43628273,
#        2.49066076, 2.54670923, 2.60442305, 2.66378506, 2.72476522,
#        2.78731991, 2.8513912 , 2.91690606, 2.98377565, 3.05189457,
#        3.12114009, 3.19137147, 3.26242914, 3.33413402, 3.40628672,
#        3.47866684, 3.55103222, 3.62311818, 3.69463676, 3.76527605,
#        3.83469935, 3.90254449, 3.96842307, 4.03191973, 4.09259136,
#        4.14996641, 4.20354413, 4.25279379, 4.297154  , 4.33603191,
#        4.36880252, 4.39480786, 4.41335633, 4.42372191, 4.42514342])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-0.97704752 -1.90854986  0.89723175  0.07847564  3.17555015]
# interception:  1.9619470013735207

# %% [markdown]
# #### Comparison

# %%
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)

plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()

# %% [markdown]
# ## 請計算模型的MSE

# %%
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.5360598307165048

# %%
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.44220987973241516

# %%
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.2662754486818878
