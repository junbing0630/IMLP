# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv("data/grades.csv")

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df['國文']
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()
# Out:
# <Axes: >

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins=15)
# Out:
# <Axes: >

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr(numeric_only=True)
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df["總級分"] = df.sum(axis=1, numeric_only=True)
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df["加權"] = df.國文+df.英文+df.數學*2

# %%
df
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 0   劉俊安   9  10  15  10  13   57  49
# 1   胡玉華  10  10  10   8   9   47  40
# 2   黃淑婷  13  15   8  11  14   61  44
# 3   陳上紫  10  10   8   9  14   51  36
# 4   崔靜成  13  12  14  12  13   64  53
# ..  ...  ..  ..  ..  ..  ..  ...  ..
# 95  蔡佳燕   9  10   9  13  14   55  37
# 96  吳筱婷   8  10  14  10  15   57  46
# 97  陳家銘  14   9  11   8  12   54  45
# 98  李明威  15   9   8   9  15   56  40
# 99  農揚勇   9  11  12  12  10   54  44
#
# [100 rows x 8 columns]

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by='總級分',ascending=False).head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 80  施雅鈴  13  15  12  13  13   66  52
# 12  李正偉  11  15  11  14  15   66  48
# 54  陳怡潔  15  15   9  15  11   65  48
# 25  蔡亦瑄  13  13  14  13  12   65  54
# 57  胡淳茜  12  15  14  13  11   65  55
# 37  曾怡君  11  12  15  13  14   65  53
# 48  陳怡婷  15  14  12   9  15   65  53
# 64  俞志峰   9  14  13  14  15   65  49
# 83  李士賢  10  14  15  13  13   65  54
# 87  趙偉希  10  13  14  13  15   65  51

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2 = df.sort_values(by=['加權','總級分'],ascending=False)

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1,101)
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  58
# 2  胡淳茜  12  15  14  13  11   65  55
# 3  詹威德  12  13  15  10  14   64  55
# 4  蔡亦瑄  13  13  14  13  12   65  54
# 5  李士賢  10  14  15  13  13   65  54

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2[df2.數學==15]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 1   吳志遠  13  15  15   8   8   59  58
# 3   詹威德  12  13  15  10  14   64  55
# 5   李士賢  10  14  15  13  13   65  54
# 7   曾怡君  11  12  15  13  14   65  53
# 10  林哲法  14   9  15  10  14   62  53
# 13  陳竹伯  10  12  15  10  14   61  52
# 15  葉儀依   9  13  15   8  14   59  52
# 18  周育霖   9  12  15  13  12   61  51
# 21  張雅彬  10  11  15  12   8   56  51
# 22  芮秋辛  11  10  15  10   8   54  51
# 25  胡勝傑   8  11  15  10  15   59  49
# 26  劉俊安   9  10  15  10  13   57  49
# 42  段冠廷   9   8  15  12  15   59  47

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df2[(df2.數學==15) & (df2.英文==15)]
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  58

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2 = df2.drop('總級分',axis=1)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 5    李士賢  10  14  15  13  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop('總級分',axis=1,inplace=True)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 5    李士賢  10  14  15  13  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [100 rows x 7 columns]

# %%
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 5    李士賢  10  14  15  13  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2.drop(5).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2.drop(5).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %%
df2.drop(df2[df2.姓名 == "李士賢"].index)
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 6    童心怡  13  13  14   8  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [99 rows x 7 columns]

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
#df = pdr.get_data_yahoo('AAPL')
import twstock
data=twstock.Stock('0056')
data.fetch_from(2024,8)
df = pd.DataFrame(data.fetch_from(2024,8))
df.head()
# Out:
#         date   capacity    turnover   open   high    low  close  change  \
# 0 2024-08-01   23174049   902136268  38.85  39.15  38.78  39.15    0.78
# 1 2024-08-02   64915191  2476724656  38.42  38.47  37.94  38.00   -1.15
# 2 2024-08-05  135847990  4812706825  37.21  37.21  34.80  35.11   -2.89
# 3 2024-08-06   82000006  2904752391  35.80  36.39  34.45  35.81    0.70
# 4 2024-08-07   30659606  1123871648  35.90  37.00  35.82  36.99    1.18
# 29 2024-09-11   17199777   639285817  37.18  37.32  37.09  37.15   -0.03
# 30 2024-09-12   13181841   496571643  37.61  37.80  37.44  37.77    0.62
# 31 2024-09-13   13223123   500458774  38.09  38.09  37.75  37.82    0.05
# 32 2024-09-16   15454898   585697347  37.90  37.98  37.82  37.98    0.16
# 33 2024-09-18   28480993  1076163488  37.97  38.00  37.56  37.72   -0.26
# 34 2024-09-19   13618023   515608458  37.72  38.07  37.62  37.97    0.25
# 35 2024-09-20   13338221   510286099  38.27  38.39  38.10  38.15    0.18
# 36 2024-09-23   15733486   601865949  38.29  38.37  38.20  38.25    0.10
# 37 2024-09-24   18360322   699362038  38.25  38.25  37.96  38.24   -0.01
# 38 2024-09-25   16028672   619738994  38.49  38.78  38.49  38.73    0.49
#
#     transaction
# 0         18368
# 1         60161
# 2        121799
# 3         54620
# 4         22798
# 5         24097
# 6         20158
# 7         18493
# 8         14859
# 9         11732
# 10        16565
# 11        17659
# 12        14463
# 13        10500
# 14        17846
# 15         9934
# 16        12243
# 17        14351
# 18        11692
# 19         7596
# 20         8577
# 21         7236
# 22        10297
# 23        11891
# 24        68321
# 25        25687
# 26        15697
# 27        29266
# 28        42220
# 29        18188
# 30         9720
# 31         9582
# 32        15036
# 33        24560
# 34        10020
# 35        11621
# 36        11981
# 37        15149
# 38        12312

# %% [markdown]
# #### 20 日的移動平均

# %%
df.close.plot()
# Out:
# <Axes: >

# %%
df.close.rolling(20).mean().plot()
# Out:
# <Axes: >

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.close.plot(legend=True)
df.close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)
# Out:
# <Axes: >

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.close.values
len(close)
# Out:
# 39

# %%
x = close[:-1]
len(x)
# Out:
# 38

# %%
y = close[1:]
len(y)
# Out:
# 38

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.55276851, -1.04635102, -1.88875659],
#        [ 0.76575386, -0.37411935,  2.28535014],
#        [-0.02485391,  0.62586837, -0.83596993],
#        [-1.84671884,  1.40632988, -0.16157318]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0 -0.552769 -1.046351 -1.888757
# 1  0.765754 -0.374119  2.285350
# 2 -0.024854  0.625868 -0.835970
# 3 -1.846719  1.406330 -0.161573

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0  1.524959 -0.253711 -0.220705
# 1 -0.321730  0.415515  0.178620
# 2  0.996931 -0.410289  0.875227

# %%
df4 = pd.concat([df2,df3],axis=0)

# %%
df4
# Out:
#           A         B         C
# 0 -0.552769 -1.046351 -1.888757
# 1  0.765754 -0.374119  2.285350
# 2 -0.024854  0.625868 -0.835970
# 3 -1.846719  1.406330 -0.161573
# 0  1.524959 -0.253711 -0.220705
# 1 -0.321730  0.415515  0.178620
# 2  0.996931 -0.410289  0.875227

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(7)

# %%
df4
# Out:
#           A         B         C
# 0 -0.552769 -1.046351 -1.888757
# 1  0.765754 -0.374119  2.285350
# 2 -0.024854  0.625868 -0.835970
# 3 -1.846719  1.406330 -0.161573
# 4  1.524959 -0.253711 -0.220705
# 5 -0.321730  0.415515  0.178620
# 6  0.996931 -0.410289  0.875227

# %% [markdown]
# #### 横向的貼

# %%
df5 = pd.concat([df2,df3],axis=1)

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.552769 -1.046351 -1.888757  1.524959 -0.253711 -0.220705
# 1  0.765754 -0.374119  2.285350 -0.321730  0.415515  0.178620
# 2 -0.024854  0.625868 -0.835970  0.996931 -0.410289  0.875227
# 3 -1.846719  1.406330 -0.161573       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_name = pd.read_csv("data/names.csv",names=['姓名'])

# %%
df_name
# Out:
#      姓名
# 0   羅雅慧
# 1   王紹尹
# 2   黃季坤
# 3   許正書
# 4   張鈞蓮
# ..  ...
# 95  陳君生
# 96  曾桂甫
# 97  林欣怡
# 98  林佳霖
# 99  胡筱芸
#
# [100 rows x 1 columns]

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades.to_csv('data/grade2.csv',index=0)

# %%
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0    6  10  10   9   9
# 1   14  14  10   9   6
# 2   13  12  10  13  13
# 3   13  15  10   6  14
# 4   10  10   6  10  12
# ..  ..  ..  ..  ..  ..
# 95   7   8  10   9   9
# 96  11   8   8   7   6
# 97   9   8   6  13   7
# 98   7  10  10  11  15
# 99   8   8  15  14  15
#
# [100 rows x 5 columns]

# %%
df_x = pd.concat([df_grades],axis=1)

# %%
df_x
# Out:
#     國文  英文  數學  社會  自然
# 0    6  10  10   9   9
# 1   14  14  10   9   6
# 2   13  12  10  13  13
# 3   13  15  10   6  14
# 4   10  10   6  10  12
# ..  ..  ..  ..  ..  ..
# 95   7   8  10   9   9
# 96  11   8   8   7   6
# 97   9   8   6  13   7
# 98   7  10  10  11  15
# 99   8   8  15  14  15
#
# [100 rows x 5 columns]
